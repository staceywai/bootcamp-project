# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
from pprint import pprint

# %%
# Import data from CSV's
data_20406 = pd.read_csv('Resources/U20406.csv')
data_20306 = pd.read_csv('Resources/U20306.csv')
data_20406.head()
# Out:
#                      Consumption Category      2015M01     2015M02  \
# 0        Personal consumption expenditures  11,767,040  11,798,728
# 1                                    Goods   4,014,969   4,022,791
# 2                            Durable goods   1,357,142   1,358,195
# 3                 Motor vehicles and parts     454,923     459,403
# 4                  New motor vehicles (55)     261,846     263,596
#
#       2015M03     2015M04     2015M05     2015M06     2015M07     2015M08  \
# 0  11,829,060  11,861,873  11,899,272  11,915,706  11,963,717  11,996,510
# 1   4,058,192   4,062,611   4,079,113   4,082,367   4,110,216   4,123,925
# 2   1,387,102   1,392,611   1,397,667   1,398,961   1,409,935   1,421,938
# 3     476,364     479,466     477,788     475,530     478,319     481,932
# 4     277,986     274,782     273,556     272,615     273,267     277,852
#
#       2015M09  ...     2019M12     2020M01     2020M02     2020M03  \
# ...

# %%
# Create a table for each year
#print(data_20406.columns)

data_2015 = data_20406.loc[:, ['Consumption Category ', '2015M01', '2015M02', '2015M03', '2015M04', '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10', '2015M11', '2015M12']]
#data_2015.dtypes

# Remove commas from strings
data_2015['2015M01'] = data_2015['2015M01'].str.replace(',', '', regex=True)
data_2015['2015M02'] = data_2015['2015M02'].str.replace(',', '', regex=True)
data_2015['2015M03'] = data_2015['2015M03'].str.replace(',', '', regex=True)
data_2015['2015M04'] = data_2015['2015M04'].str.replace(',', '', regex=True)
data_2015['2015M05'] = data_2015['2015M05'].str.replace(',', '', regex=True)
data_2015['2015M06'] = data_2015['2015M06'].str.replace(',', '', regex=True)
data_2015['2015M07'] = data_2015['2015M07'].str.replace(',', '', regex=True)
data_2015['2015M08'] = data_2015['2015M08'].str.replace(',', '', regex=True)
data_2015['2015M09'] = data_2015['2015M09'].str.replace(',', '', regex=True)
data_2015['2015M10'] = data_2015['2015M10'].str.replace(',', '', regex=True)
data_2015['2015M11'] = data_2015['2015M11'].str.replace(',', '', regex=True)
data_2015['2015M12'] = data_2015['2015M12'].str.replace(',', '', regex=True)
data_2015.head()
# Out:
#                      Consumption Category    2015M01   2015M02   2015M03  \
# 0        Personal consumption expenditures  11767040  11798728  11829060
# 1                                    Goods   4014969   4022791   4058192
# 2                            Durable goods   1357142   1358195   1387102
# 3                 Motor vehicles and parts    454923    459403    476364
# 4                  New motor vehicles (55)    261846    263596    277986
#
#     2015M04   2015M05   2015M06   2015M07   2015M08   2015M09   2015M10  \
# 0  11861873  11899272  11915706  11963717  11996510  12013327  12022367
# 1   4062611   4079113   4082367   4110216   4123925   4127108   4109067
# 2   1392611   1397667   1398961   1409935   1421938   1414141   1408426
# 3    479466    477788    475530    478319    481932    475228    467143
# 4    274782    273556    272615    273267    277852    270609    263263
#
#     2015M11   2015M12
# 0  12049883  12093803
# 1   4141713   4158581
# 2   1428340   1433089
# ...
