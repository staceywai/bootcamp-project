# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
from pprint import pprint

# %%
# Import data from CSV's
grocery_data = pd.read_csv('../Resources/grocery_consumption_19_20.csv')
grocery_data
# Out:
#                         Grocery Consumption Category   2019M01  2019M02  \
# 0                         Cereals and bakery products   142349   139160
# 1                                   Meats and poultry   162972   158595
# 2                                    Fish and seafood    13586    13216
# 3                        Milk dairy products and eggs    89712    88129
# 4                                       Fats and oils    23724    23232
# 5                         Fresh fruits and vegetables    83285    81046
# 6                     Processed fruits and vegetables    30991    29927
# 7                                    Sugar and sweets    47493    46588
# 8              Food products not elsewhere classified   151454   147410
# 9             Coffee tea and other beverage materials    17512    17122
# 10            Mineral waters soft drinks and veget...    79929    78135
# 11            Alcoholic beverages purchased for of...   136945   135327
#
# ...

# %%
grocery_data.columns
# Out:
# Index(['Grocery Consumption Category ', '2019M01', '2019M02', '2019M03',
#        '2019M04', '2019M05', '2019M06', '2019M07', '2019M08', '2019M09',
#        '2019M10', '2019M11', '2019M12', '2020M01', '2020M02', '2020M03',
#        '2020M04', '2020M05', '2020M06', '2020M07', '2020M08', '2020M09'],
#       dtype='object')

# %%
grocery_data.transpose()
# Out:
#                                                                   0   \
# Grocery Consumption Category             Cereals and bakery products
# 2019M01                                                       142349
# 2019M02                                                       139160
# 2019M03                                                       140742
# 2019M04                                                       141714
# 2019M05                                                       141374
# 2019M06                                                       142700
# 2019M07                                                       143963
# 2019M08                                                       144391
# 2019M09                                                       142633
# 2019M10                                                       142962
# 2019M11                                                       142816
# 2019M12                                                       142791
# ...

# %%
# # Create a table for each year
# #print(data_20406.columns)

# data_2015 = data_20406.loc[:, ['Consumption Category ', '2015M01', '2015M02', '2015M03', '2015M04', '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10', '2015M11', '2015M12']]
# data_2015.dtypes
# #data_2015.head()
# # data_2015['Year Data'] = data_2015.sum(axis=1)
# # data_2015.head()
# #data_2015['2015M01', '2015M02', '2015M03', '2015M04', '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10', '2015M11', '2015M12'] = pd.to_numeric(data_2015['2015M01', '2015M02', '2015M03', '2015M04', '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10', '2015M11', '2015M12'])
# data_2015 = data_2015['2015M01'] .str.replace(',', '', regex=True)
# data_2015.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('2015M01', '2015M02', '2015M03', '2015M04', '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10', '2015M11', '2015M12')
#
# During handling of the above exception, another exception occurred:
#
# ...
