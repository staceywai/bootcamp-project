# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
from pprint import pprint

# %%
#2015-2020 Analysis for Nondurable Goods

# %%
# necessity items

necessities = pd.read_csv('Resources/necessityitems_consumption_15_20.csv')
necessities
# Out:
#                                 Consumption Category   2015M01  2015M02  \
# 0                       Gasoline and other motor fuel   409147   409566
# 1                               Lubricants and fluids     7997     7750
# 2                                            Fuel oil    28549    33918
# 3                                         Other fuels     1973     2344
# 4                                  Prescription drugs   338316   335646
# 5                               Nonprescription drugs    63661    63165
# 6                              Other medical products     5257     5249
# 7                         Household cleaning products    36698    36301
# 8                            Household paper products    36414    36067
# 9                                    Household linens    41471    41486
# 10                                       Sewing items     1737     1729
# 11                   Miscellaneous household products    14689    14958
# 12  Hair dental shaving and miscellaneous personal...    68256    67761
# 13  Cosmetic / perfumes / bath / nail preparations...    45634    46092
# 14              Electric appliances for personal care     7767     7698
# 15                                            Tobacco    86978    86681
#
#     2015M03  2015M04  2015M05  2015M06  2015M07  2015M08  2015M09  ...  \
# 0    410240   413904   414094   414063   417522   416371   420458  ...
# 1      7627     7552     7361     7284     7222     7093     7110  ...
# 2     27675    26561    25071    25363    25709    26083    26810  ...
# 3      2053     1845     1782     1809     1796     1730     1736  ...
# 4    338817   339516   342481   344160   347730   350601   350147  ...
# 5     64196    63846    63865    65068    65258    65426    66007  ...
# 6      5271     5258     5237     5335     5434     5475     5381  ...
# 7     36282    35978    36021    36172    36323    36534    36737  ...
# 8     36221    35835    36243    36405    36509    36564    36781  ...
# 9     42591    42450    42927    42092    42803    43223    43234  ...
# 10     1714     1692     1710     1723     1688     1719     1716  ...
# 11    14967    15224    15351    15503    15817    15816    16033  ...
# 12    68382    68294    68689    69369    69869    70388    70819  ...
# 13    46464    46453    46849    47042    47650    47831    47136  ...
# 14     7798     7822     7881     7900     7973     8023     8060  ...
# 15    86546    86871    86428    85896    85892    85903    85875  ...
#
#     2019M12  2020M01  2020M02  2020M03  2020M04  2020M05  2020M06  2020M07  \
# 0    403003   414196   412515   348239   258098   312138   352503   363811
# 1      7358     7555     7541     6383     4743     5721     6446     6656
# 2     21250    19725    21692    23366    27167    30496    27746    26913
# 3      1497     1428     1438     1347     1361     1418     1388     1398
# 4    393525   397892   404197   429613   392311   396323   404648   408873
# 5     77449    78626    79126    85388    76229    79927    82875    85731
# 6      6523     6612     6614     6215     5233     5800     6284     6791
# 7     39571    39791    40017    46227    40557    42437    42594    41637
# 8     37652    38042    37937    44706    37601    39052    39452    37998
# 9     56232    53555    52812    50236    42161    51225    54864    56319
# 10     1838     1836     1834     1755     1490     2008     2337     2223
# 11    25447    25758    26018    27188    28790    30868    30593    30667
# 12    77037    77612    76724    83456    73333    77951    81100    82083
# 13    58299    58502    57799    55158    47674    54279    57943    60614
# 14     9883    10057     9963    10223     9608    10812    11225    11176
# 15    74907    74734    74105    74144    75486    76160    76651    76431
#
#     2020M08  2020M09
# 0    369140   374007
# 1      6742     6831
# 2     26182    28497
# 3      1425     1479
# 4    412429   417457
# 5     84330    84740
# 6      6945     7151
# 7     41494    41810
# 8     37965    39656
# 9     56326    56894
# 10     1904     2040
# 11    30730    31106
# 12    81309    82306
# 13    60911    62634
# 14    11119    11249
# 15    76224    75988
#
# [16 rows x 70 columns]

# %%
consumption15_consumption_19 = necessities[['Consumption Category ', '2015M01', '2015M02', '2015M03', '2015M04',
       '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10',
       '2015M11', '2015M12', '2016M01', '2016M02', '2016M03', '2016M04',
       '2016M05', '2016M06', '2016M07', '2016M08', '2016M09', '2016M10',
       '2016M11', '2016M12', '2017M01', '2017M02', '2017M03', '2017M04',
       '2017M05', '2017M06', '2017M07', '2017M08', '2017M09', '2017M10',
       '2017M11', '2017M12', '2018M01', '2018M02', '2018M03', '2018M04',
       '2018M05', '2018M06', '2018M07', '2018M08', '2018M09', '2018M10',
       '2018M11', '2018M12', '2019M01', '2019M02', '2019M03', '2019M04',
       '2019M05', '2019M06', '2019M07', '2019M08', '2019M09', '2019M10',
       '2019M11', '2019M12']]

consumption15_consumption_19 = consumption15_consumption_19.set_index('Consumption Category ')
consumption15_consumption_19
# Out:
#                                                     2015M01  2015M02  2015M03  \
# Consumption Category
# Gasoline and other motor fuel                        409147   409566   410240
# Lubricants and fluids                                  7997     7750     7627
# Fuel oil                                              28549    33918    27675
# Other fuels                                            1973     2344     2053
# Prescription drugs                                   338316   335646   338817
# Nonprescription drugs                                 63661    63165    64196
# Other medical products                                 5257     5249     5271
# Household cleaning products                           36698    36301    36282
# Household paper products                              36414    36067    36221
# Household linens                                      41471    41486    42591
# Sewing items                                           1737     1729     1714
# Miscellaneous household products                      14689    14958    14967
# Hair dental shaving and miscellaneous personal ...    68256    67761    68382
# Cosmetic / perfumes / bath / nail preparations ...    45634    46092    46464
# Electric appliances for personal care                  7767     7698     7798
# Tobacco                                               86978    86681    86546
#
#                                                     2015M04  2015M05  2015M06  \
# Consumption Category
# Gasoline and other motor fuel                        413904   414094   414063
# Lubricants and fluids                                  7552     7361     7284
# Fuel oil                                              26561    25071    25363
# Other fuels                                            1845     1782     1809
# Prescription drugs                                   339516   342481   344160
# Nonprescription drugs                                 63846    63865    65068
# Other medical products                                 5258     5237     5335
# Household cleaning products                           35978    36021    36172
# Household paper products                              35835    36243    36405
# Household linens                                      42450    42927    42092
# Sewing items                                           1692     1710     1723
# Miscellaneous household products                      15224    15351    15503
# Hair dental shaving and miscellaneous personal ...    68294    68689    69369
# Cosmetic / perfumes / bath / nail preparations ...    46453    46849    47042
# Electric appliances for personal care                  7822     7881     7900
# Tobacco                                               86871    86428    85896
#
#                                                     2015M07  2015M08  2015M09  \
# Consumption Category
# Gasoline and other motor fuel                        417522   416371   420458
# Lubricants and fluids                                  7222     7093     7110
# Fuel oil                                              25709    26083    26810
# Other fuels                                            1796     1730     1736
# Prescription drugs                                   347730   350601   350147
# Nonprescription drugs                                 65258    65426    66007
# Other medical products                                 5434     5475     5381
# Household cleaning products                           36323    36534    36737
# Household paper products                              36509    36564    36781
# Household linens                                      42803    43223    43234
# Sewing items                                           1688     1719     1716
# Miscellaneous household products                      15817    15816    16033
# Hair dental shaving and miscellaneous personal ...    69869    70388    70819
# Cosmetic / perfumes / bath / nail preparations ...    47650    47831    47136
# Electric appliances for personal care                  7973     8023     8060
# Tobacco                                               85892    85903    85875
#
#                                                     2015M10  ...  2019M03  \
# Consumption Category                                         ...
# Gasoline and other motor fuel                        416831  ...   411127
# Lubricants and fluids                                  7008  ...     7545
# Fuel oil                                              26608  ...    24371
# Other fuels                                            1662  ...     1677
# Prescription drugs                                   353385  ...   386897
# Nonprescription drugs                                 65706  ...    76869
# Other medical products                                 5489  ...     6504
# Household cleaning products                           36618  ...    39233
# Household paper products                              36539  ...    37969
# Household linens                                      43720  ...    52048
# Sewing items                                           1645  ...     1689
# Miscellaneous household products                      16165  ...    23177
# Hair dental shaving and miscellaneous personal ...    70207  ...    77109
# Cosmetic / perfumes / bath / nail preparations ...    47224  ...    56000
# Electric appliances for personal care                  8027  ...     9748
# Tobacco                                               85615  ...    76356
#
#                                                     2019M04  2019M05  2019M06  \
# Consumption Category
# Gasoline and other motor fuel                        419375   411998   413314
# Lubricants and fluids                                  7660     7535     7555
# Fuel oil                                              23015    22774    23604
# Other fuels                                            1610     1589     1638
# Prescription drugs                                   381678   386486   390877
# Nonprescription drugs                                 76924    77264    77546
# Other medical products                                 6409     6423     6428
# Household cleaning products                           39404    39403    39517
# Household paper products                              38330    38133    38033
# Household linens                                      53455    53907    55545
# Sewing items                                           1762     1810     1785
# Miscellaneous household products                      23666    24610    24898
# Hair dental shaving and miscellaneous personal ...    76955    77276    77755
# Cosmetic / perfumes / bath / nail preparations ...    56205    57360    57518
# Electric appliances for personal care                  9809     9887     9969
# Tobacco                                               76414    76836    76713
#
#                                                     2019M07  2019M08  2019M09  \
# Consumption Category
# Gasoline and other motor fuel                        410698   417331   411279
# Lubricants and fluids                                  7506     7612     7489
# Fuel oil                                              23258    23221    22515
# Other fuels                                            1621     1618     1587
# Prescription drugs                                   392962   396058   397687
# Nonprescription drugs                                 77802    76594    77062
# Other medical products                                 6545     6531     6584
# Household cleaning products                           39833    39976    39676
# Household paper products                              38614    38772    38374
# Household linens                                      55025    54317    53697
# Sewing items                                           1764     1827     1843
# Miscellaneous household products                      24911    25455    25403
# Hair dental shaving and miscellaneous personal ...    77542    77648    77703
# Cosmetic / perfumes / bath / nail preparations ...    57244    56709    56859
# Electric appliances for personal care                  9963    10017     9998
# Tobacco                                               76422    76261    75758
#
#                                                     2019M10  2019M11  2019M12
# Consumption Category
# Gasoline and other motor fuel                        417060   411946   403003
# Lubricants and fluids                                  7564     7541     7358
# Fuel oil                                              22061    23684    21250
# Other fuels                                            1565     1699     1497
# Prescription drugs                                   394365   395888   393525
# Nonprescription drugs                                 77640    76750    77449
# Other medical products                                 6565     6495     6523
# Household cleaning products                           39837    39746    39571
# Household paper products                              38328    37732    37652
# Household linens                                      54748    56545    56232
# Sewing items                                           1860     1805     1838
# Miscellaneous household products                      25597    25368    25447
# Hair dental shaving and miscellaneous personal ...    77575    76797    77037
# Cosmetic / perfumes / bath / nail preparations ...    57414    57563    58299
# Electric appliances for personal care                  9989     9879     9883
# Tobacco                                               75170    74817    74907
#
# [16 rows x 60 columns]

# %%
necessities15 = necessities.loc[:, ['Consumption Category ', '2015M01', '2015M02', '2015M03', '2015M04',
       '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10','2015M11', '2015M12']]
totalNecessities15 = necessities15.sum(axis=1)
necessities15['Total'] = totalNecessities15
necessities15 

necessities16 = necessities.loc[:, ['Consumption Category ', '2016M01', '2016M02', '2016M03', '2016M04',
       '2016M05', '2016M06', '2016M07', '2016M08', '2016M09', '2016M10','2016M11', '2016M12']]
totalNecessities16 = necessities16.sum(axis=1)
necessities16['Total'] = totalNecessities16
necessities16

necessities17 = necessities.loc[:, ['Consumption Category ', '2017M01', '2017M02', '2017M03', '2017M04',
       '2017M05', '2017M06', '2017M07', '2017M08', '2017M09', '2017M10','2017M11', '2017M12']]
totalNecessities17 = necessities17.sum(axis=1)
necessities17['Total'] = totalNecessities17
necessities17

necessities18 = necessities.loc[:, ['Consumption Category ', '2018M01', '2018M02', '2018M03', '2018M04',
       '2018M05', '2018M06', '2018M07', '2018M08', '2018M09', '2018M10','2018M11', '2018M12']]
totalNecessities18 = necessities18.sum(axis=1)
necessities18['Total'] = totalNecessities18
necessities18

necessities19 = necessities.loc[:, ['Consumption Category ', '2019M01', '2019M02', '2019M03', '2019M04',
       '2019M05', '2019M06', '2019M07', '2019M08', '2019M09', '2019M10','2019M11', '2019M12']]
totalNecessities19 = necessities19.sum(axis=1)
necessities19['Total'] = totalNecessities19
necessities19

necessities15
necessities16
necessities17
necessities18
necessities19
# Out:
#                                 Consumption Category   2019M01  2019M02  \
# 0                       Gasoline and other motor fuel   416232   413890
# 1                               Lubricants and fluids     7617     7591
# 2                                            Fuel oil    24220    23751
# 3                                         Other fuels     1614     1628
# 4                                  Prescription drugs   376230   383557
# 5                               Nonprescription drugs    76356    76578
# 6                              Other medical products     6348     6393
# 7                         Household cleaning products    39808    39000
# 8                            Household paper products    38486    38043
# 9                                    Household linens    50275    52134
# 10                                       Sewing items     1777     1744
# 11                   Miscellaneous household products    22977    23197
# 12  Hair dental shaving and miscellaneous personal...    76378    76206
# 13  Cosmetic / perfumes / bath / nail preparations...    55225    55691
# 14              Electric appliances for personal care     9649     9681
# 15                                            Tobacco    78345    77777
#
#     2019M03  2019M04  2019M05  2019M06  2019M07  2019M08  2019M09  2019M10  \
# 0    411127   419375   411998   413314   410698   417331   411279   417060
# 1      7545     7660     7535     7555     7506     7612     7489     7564
# 2     24371    23015    22774    23604    23258    23221    22515    22061
# 3      1677     1610     1589     1638     1621     1618     1587     1565
# 4    386897   381678   386486   390877   392962   396058   397687   394365
# 5     76869    76924    77264    77546    77802    76594    77062    77640
# 6      6504     6409     6423     6428     6545     6531     6584     6565
# 7     39233    39404    39403    39517    39833    39976    39676    39837
# 8     37969    38330    38133    38033    38614    38772    38374    38328
# 9     52048    53455    53907    55545    55025    54317    53697    54748
# 10     1689     1762     1810     1785     1764     1827     1843     1860
# 11    23177    23666    24610    24898    24911    25455    25403    25597
# 12    77109    76955    77276    77755    77542    77648    77703    77575
# 13    56000    56205    57360    57518    57244    56709    56859    57414
# 14     9748     9809     9887     9969     9963    10017     9998     9989
# 15    76356    76414    76836    76713    76422    76261    75758    75170
#
#     2019M11  2019M12    Total
# 0    411946   403003  4957253
# 1      7541     7358    90573
# 2     23684    21250   277724
# 3      1699     1497    19343
# 4    395888   393525  4676210
# 5     76750    77449   924834
# 6      6495     6523    77748
# 7     39746    39571   475004
# 8     37732    37652   458466
# 9     56545    56232   647928
# 10     1805     1838    21504
# 11    25368    25447   294706
# 12    76797    77037   925981
# 13    57563    58299   682087
# 14     9879     9883   118472
# 15    74817    74907   915776

# %%
graph_necessities_df = consumption15_consumption_19
graph_necessities_df

allmonths = graph_necessities_df.keys()
allmonths = ["Jan15","Feb15","March15","April15","May15","June15","July15","August15","Sept15","Oct15","Nov15","Dec15",
            "Jan16","Feb16","March16","April16","May16","June16","July16","August16","Sept16","Oct16","Nov16","Dec16",
            "Jan17","Feb17","March17","April17","May17","June17","July17","August17","Sept17","Oct17","Nov17","Dec17",
            "Jan18","Feb18","March18","April18","May18","June18","July18","August18","Sept18","Oct18","Nov18","Dec18",
            "Jan19","Feb19","March19","April19","May19","June19","July19","August19","Sept19","Oct19","Nov19","Dec19"
         ]

# %%
#Cleaning Prodcuts 2015-2019
cleaningproduct15_19 = plt.plot(allmonths, graph_necessities_df.loc['Household cleaning products', :], color="green", label="Cleaning Product Consumption")

plt.title("2015-2019 Cleaning Product Consumption (By Month)")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
# Gasoline & Motor Fuel 2015-2019

gasoline15_19 = plt.plot(allmonths, graph_necessities_df.loc['Gasoline and other motor fuel', :], color="green", label="Gasosline Consumption")

plt.title("2015-2019 Gasoline & Motor Fuel Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
#Prescription Drugs 2015-2019
prescription15_19 = plt.plot(allmonths, graph_necessities_df.loc['Prescription drugs', :], color="green", label="Prescription Drugs")

plt.title("2015-2019 Prescription Drug Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
# Nonprescription Drug 2015-2019

nonprescription15_19 = plt.plot(allmonths, graph_necessities_df.loc['Nonprescription drugs', :], color="green", label="Nonprescription Drugs")

plt.title("2015-2019 Nonprescription Drug Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
# Other Medical 2015-2019

othermedical15_19 = plt.plot(allmonths, graph_necessities_df.loc['Other medical products', :], color="green", label="Other Medical Products Consumption")

plt.title("2015-2019 Other Medical Product Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
# Other Medical 2015-2019

householdpaper15_19 = plt.plot(allmonths, graph_necessities_df.loc['Household paper products', :], color="green", label="Other Medical Products Consumption")

plt.title("2015-2019 Household Paper Product Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
annualtotal_df = pd.DataFrame({
    'Category': necessities['Consumption Category '],
    '2015 Total': necessities15['Total'],
    '2016 Total': necessities16['Total'],
    '2017 Total': necessities17['Total'],
    '2018 Total': necessities18['Total'],
    '2019 Total': necessities19['Total']
})

annual_df = annualtotal_df.set_index('Category')

years = annual_df.keys()
years = ["2015","2016","2017","2018","2019"]

annual_df
# Out:
#                                                     2015 Total  2016 Total  \
# Category
# Gasoline and other motor fuel                          4979314     5021915
# Lubricants and fluids                                    87977       83281
# Fuel oil                                                318503      313603
# Other fuels                                              21513       17959
# Prescription drugs                                     4147739     4153517
# Nonprescription drugs                                   779596      821474
# Other medical products                                   64525       69096
# Household cleaning products                             437364      446074
# Household paper products                                436878      443705
# Household linens                                        513427      545675
# Sewing items                                             20388       20938
# Miscellaneous household products                        187206      212066
# Hair dental shaving and miscellaneous personal ...      833926      857913
# Cosmetic / perfumes / bath / nail preparations ...      563677      583948
# Electric appliances for personal care                    95180       99494
# Tobacco                                                1034298     1017584
#
#                                                     2017 Total  2018 Total  \
# Category
# Gasoline and other motor fuel                          4997268     4971962
# Lubricants and fluids                                    85927       91099
# Fuel oil                                                301485      285773
# Other fuels                                              18339       20133
# Prescription drugs                                     4238247     4339078
# Nonprescription drugs                                   844103      880575
# Other medical products                                   71185       73875
# Household cleaning products                             464378      475839
# Household paper products                                455442      465018
# Household linens                                        583895      605290
# Sewing items                                             22935       22530
# Miscellaneous household products                        239096      259487
# Hair dental shaving and miscellaneous personal ...      881222      906660
# Cosmetic / perfumes / bath / nail preparations ...      606551      636242
# Electric appliances for personal care                   106823      112889
# Tobacco                                                 974600      952961
#
#                                                     2019 Total
# Category
# Gasoline and other motor fuel                          4957253
# Lubricants and fluids                                    90573
# Fuel oil                                                277724
# Other fuels                                              19343
# Prescription drugs                                     4676210
# Nonprescription drugs                                   924834
# Other medical products                                   77748
# Household cleaning products                             475004
# Household paper products                                458466
# Household linens                                        647928
# Sewing items                                             21504
# Miscellaneous household products                        294706
# Hair dental shaving and miscellaneous personal ...      925981
# Cosmetic / perfumes / bath / nail preparations ...      682087
# Electric appliances for personal care                   118472
# Tobacco                                                 915776

# %%
# 2015-2019 Annual Total Cleaning Product Consumption Comparison

cleaningproducts = plt.plot(years, annual_df.loc['Household cleaning products',['2015 Total', '2016 Total',
                                    '2017 Total', '2018 Total', '2019 Total']], color="orange", label="Cleaning Products")

gasoline = plt.plot(years, annual_df.loc['Gasoline and other motor fuel',['2015 Total', '2016 Total', 
                                    '2017 Total', '2018 Total', '2019 Total']], color="pink", label="Gasoline")

prescription = plt.plot(years, annual_df.loc['Prescription drugs',['2015 Total', '2016 Total',
                                    '2017 Total', '2018 Total', '2019 Total']], color="green", label="Prescription Drugs")

nonprescription = plt.plot(years, annual_df.loc['Nonprescription drugs',['2015 Total', '2016 Total',
                                    '2017 Total', '2018 Total', '2019 Total']], color="blue", label="Nonprescription Drugs")

othermedical = plt.plot(years, annual_df.loc['Other medical products',['2015 Total', '2016 Total',
                                    '2017 Total', '2018 Total', '2019 Total']], color="red", label="Other Medical")

householdpaper = plt.plot(years, annual_df.loc['Household paper products',['2015 Total', '2016 Total',
                                    '2017 Total', '2018 Total', '2019 Total']], color="black", label="Paper Products")


plt.legend(['Cleaning Products', 'Gasoline', 'Prescription Drugs', 'Nonprescription Drugs', 'Other Medical','Household Paper Prodcuts'], loc="best")
plt.title("2015-2019 Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
graph15_df = graph_necessities_df[['2015M01', '2015M02', '2015M03', '2015M04',
       '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10','2015M11', '2015M12']]
months = graph15_df.keys()
months = ["Jan","Feb","March","April","May","June","July","August","Sept","Oct","Nov","Dec"]

graph16_df = graph_necessities_df[['2016M01', '2016M02', '2016M03', '2016M04',
       '2016M05', '2016M06', '2016M07', '2016M08', '2016M09', '2016M10','2016M11', '2016M12']]
months = graph16_df.keys()
months = ["Jan","Feb","March","April","May","June","July","August","Sept","Oct","Nov","Dec"]

graph17_df = graph_necessities_df[['2017M01', '2017M02', '2017M03', '2017M04',
       '2017M05', '2017M06', '2017M07', '2017M08', '2017M09', '2017M10', '2017M11', '2017M12']]
months = graph17_df.keys()
months = ["Jan","Feb","March","April","May","June","July","August","Sept","Oct","Nov","Dec"]

graph18_df = graph_necessities_df[['2018M01', '2018M02', '2018M03', '2018M04',
        '2018M05', '2018M06', '2018M07', '2018M08', '2018M09', '2018M10','2018M11', '2018M12']]
months = graph18_df.keys()
months = ["Jan","Feb","March","April","May","June","July","August","Sept","Oct","Nov","Dec"]

graph19_df = graph_necessities_df[['2019M01', '2019M02', '2019M03', '2019M04',
        '2019M05', '2019M06', '2019M07', '2019M08', '2019M09', '2019M10','2019M11', '2019M12']]
months = graph19_df.keys()
months = ["Jan","Feb","March","April","May","June","July","August","Sept","Oct","Nov","Dec"]

# %%
# 2015-2019 Cleaning Product Consumption Comparison

cleaningproduct15 = plt.plot(months, graph15_df.loc['Household cleaning products', :], color="orange", label="2015")

cleaningproduct16 = plt.plot(months, graph16_df.loc['Household cleaning products', :], color="pink", label="2016")

cleaningproduct17 = plt.plot(months, graph17_df.loc['Household cleaning products', :], color="green", label="2017")

cleaningproduct18 = plt.plot(months, graph18_df.loc['Household cleaning products', :], color="blue", label="2018")

cleaningproduct19 = plt.plot(months, graph19_df.loc['Household cleaning products', :], color="red", label="2019")

plt.legend([2015, 2016, 2017, 2018, 2019], loc="best")
plt.title("2015-2019 Cleaning Product Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
# 2015-2019 Prescription Drugs Consumption Comparison

prescription15 = plt.plot(months, graph15_df.loc['Prescription drugs',['2015M01', '2015M02', '2015M03', '2015M04',
       '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10',
       '2015M11', '2015M12']], color="orange", label="2015")

prescription16 = plt.plot(months, graph16_df.loc['Prescription drugs',['2016M01', '2016M02', '2016M03', '2016M04',
       '2016M05', '2016M06', '2016M07', '2016M08', '2016M09', '2016M10',
       '2016M11', '2016M12']], color="pink", label="2016")

prescription17 = plt.plot(months, graph17_df.loc['Prescription drugs',['2017M01', '2017M02', '2017M03', '2017M04',
       '2017M05', '2017M06', '2017M07', '2017M08', '2017M09', '2017M10',
       '2017M11', '2017M12']], color="green", label="2017")

prescription18 = plt.plot(months, graph18_df.loc['Prescription drugs',['2018M01', '2018M02', '2018M03', '2018M04',
       '2018M05', '2018M06', '2018M07', '2018M08', '2018M09', '2018M10',
       '2018M11', '2018M12']], color="blue", label="2018")

prescription19 = plt.plot(months, graph19_df.loc['Prescription drugs',['2019M01', '2019M02', '2019M03', '2019M04',
       '2019M05', '2019M06', '2019M07', '2019M08', '2019M09', '2019M10',
       '2019M11', '2019M12']], color="red", label="2019")

plt.legend([2015, 2016, 2017, 2018, 2019], loc="best")
plt.title("2015-2019 Prescription Drug Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
# 2015-2019 Nonprescription Drugs Consumption Comparison

nonprescription15 = plt.plot(months, graph15_df.loc['Nonprescription drugs',['2015M01', '2015M02', '2015M03', '2015M04',
       '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10',
       '2015M11', '2015M12']], color="orange", label="2015")

nonprescription16 = plt.plot(months, graph16_df.loc['Nonprescription drugs',['2016M01', '2016M02', '2016M03', '2016M04',
       '2016M05', '2016M06', '2016M07', '2016M08', '2016M09', '2016M10',
       '2016M11', '2016M12']], color="pink", label="2016")

nonprescription17 = plt.plot(months, graph17_df.loc['Nonprescription drugs',['2017M01', '2017M02', '2017M03', '2017M04',
       '2017M05', '2017M06', '2017M07', '2017M08', '2017M09', '2017M10',
       '2017M11', '2017M12']], color="green", label="2017")

nonprescription18 = plt.plot(months, graph18_df.loc['Nonprescription drugs',['2018M01', '2018M02', '2018M03', '2018M04',
       '2018M05', '2018M06', '2018M07', '2018M08', '2018M09', '2018M10',
       '2018M11', '2018M12']], color="blue", label="2018")

nonprescription19 = plt.plot(months, graph19_df.loc['Nonprescription drugs',['2019M01', '2019M02', '2019M03', '2019M04',
       '2019M05', '2019M06', '2019M07', '2019M08', '2019M09', '2019M10',
       '2019M11', '2019M12']], color="red", label="2019")

plt.legend([2015, 2016, 2017, 2018, 2019], loc="best")
plt.title("2015-2019 Nonprescription Drug Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
# 2015-2019 Other Medical Product Consumption Comparison

othermedicalproduct15 = plt.plot(months, graph15_df.loc['Other medical products',['2015M01', '2015M02', '2015M03', '2015M04',
       '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10',
       '2015M11', '2015M12']], color="orange", label="2015")

othermedicalproduct16 = plt.plot(months, graph16_df.loc['Other medical products',['2016M01', '2016M02', '2016M03', '2016M04',
       '2016M05', '2016M06', '2016M07', '2016M08', '2016M09', '2016M10',
       '2016M11', '2016M12']], color="pink", label="2016")

othermedicalproduct17 = plt.plot(months, graph17_df.loc['Other medical products',['2017M01', '2017M02', '2017M03', '2017M04',
       '2017M05', '2017M06', '2017M07', '2017M08', '2017M09', '2017M10',
       '2017M11', '2017M12']], color="green", label="2017")

othermedicalproduct18 = plt.plot(months, graph18_df.loc['Other medical products',['2018M01', '2018M02', '2018M03', '2018M04',
       '2018M05', '2018M06', '2018M07', '2018M08', '2018M09', '2018M10',
       '2018M11', '2018M12']], color="blue", label="2018")

othermedicalproduct19 = plt.plot(months, graph19_df.loc['Other medical products',['2019M01', '2019M02', '2019M03', '2019M04',
       '2019M05', '2019M06', '2019M07', '2019M08', '2019M09', '2019M10',
       '2019M11', '2019M12']], color="red", label="2019")

plt.legend([2015, 2016, 2017, 2018, 2019], loc="best")
plt.title("2015-2019 Other Medical Produts Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
# 2015-2019 Gasoline & Motor Fuel Consumption Comparison

gasoline15 = plt.plot(months, graph15_df.loc['Gasoline and other motor fuel',['2015M01', '2015M02', '2015M03', '2015M04',
       '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10',
       '2015M11', '2015M12']], color="orange", label="2015")

gasoline16 = plt.plot(months, graph16_df.loc['Gasoline and other motor fuel',['2016M01', '2016M02', '2016M03', '2016M04',
       '2016M05', '2016M06', '2016M07', '2016M08', '2016M09', '2016M10',
       '2016M11', '2016M12']], color="pink", label="2016")

gasoline17 = plt.plot(months, graph17_df.loc['Gasoline and other motor fuel',['2017M01', '2017M02', '2017M03', '2017M04',
       '2017M05', '2017M06', '2017M07', '2017M08', '2017M09', '2017M10',
       '2017M11', '2017M12']], color="green", label="2017")

gasoline18 = plt.plot(months, graph18_df.loc['Gasoline and other motor fuel',['2018M01', '2018M02', '2018M03', '2018M04',
       '2018M05', '2018M06', '2018M07', '2018M08', '2018M09', '2018M10',
       '2018M11', '2018M12']], color="blue", label="2018")

gasoline19 = plt.plot(months, graph19_df.loc['Gasoline and other motor fuel',['2019M01', '2019M02', '2019M03', '2019M04',
       '2019M05', '2019M06', '2019M07', '2019M08', '2019M09', '2019M10',
       '2019M11', '2019M12']], color="red", label="2019")

plt.legend([2015, 2016, 2017, 2018, 2019], loc="best")
plt.title("2015-2019 Gasoline & Motor Fuel Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
# 2015-2019 Household Paper Products Consumption Comparison

paper15 = plt.plot(months, graph15_df.loc['Household paper products',['2015M01', '2015M02', '2015M03', '2015M04',
       '2015M05', '2015M06', '2015M07', '2015M08', '2015M09', '2015M10',
       '2015M11', '2015M12']], color="orange", label="2015")

paper16 = plt.plot(months, graph16_df.loc['Household paper products',['2016M01', '2016M02', '2016M03', '2016M04',
       '2016M05', '2016M06', '2016M07', '2016M08', '2016M09', '2016M10',
       '2016M11', '2016M12']], color="pink", label="2016")

paper17 = plt.plot(months, graph17_df.loc['Household paper products',['2017M01', '2017M02', '2017M03', '2017M04',
       '2017M05', '2017M06', '2017M07', '2017M08', '2017M09', '2017M10',
       '2017M11', '2017M12']], color="green", label="2017")

paper18 = plt.plot(months, graph18_df.loc['Household paper products',['2018M01', '2018M02', '2018M03', '2018M04',
       '2018M05', '2018M06', '2018M07', '2018M08', '2018M09', '2018M10',
       '2018M11', '2018M12']], color="blue", label="2018")

paper19 = plt.plot(months, graph19_df.loc['Household paper products',['2019M01', '2019M02', '2019M03', '2019M04',
       '2019M05', '2019M06', '2019M07', '2019M08', '2019M09', '2019M10',
       '2019M11', '2019M12']], color="red", label="2019")

plt.legend([2015, 2016, 2017, 2018, 2019], loc="best")
plt.title("2015-2019 Household Paper Product Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
# 2015 - 2020 Analysis (Jan-Sept)

necessities20 = necessities.loc[:, ['Consumption Category ', '2020M01', '2020M02', '2020M03', '2020M04',
       '2020M05', '2020M06', '2020M07', '2020M08', '2020M09']]

necessities20

graph_necessities20 = necessities20.set_index('Consumption Category ')
graph_necessities20
# Out:
#                                                     2020M01  2020M02  2020M03  \
# Consumption Category
# Gasoline and other motor fuel                        414196   412515   348239
# Lubricants and fluids                                  7555     7541     6383
# Fuel oil                                              19725    21692    23366
# Other fuels                                            1428     1438     1347
# Prescription drugs                                   397892   404197   429613
# Nonprescription drugs                                 78626    79126    85388
# Other medical products                                 6612     6614     6215
# Household cleaning products                           39791    40017    46227
# Household paper products                              38042    37937    44706
# Household linens                                      53555    52812    50236
# Sewing items                                           1836     1834     1755
# Miscellaneous household products                      25758    26018    27188
# Hair dental shaving and miscellaneous personal ...    77612    76724    83456
# Cosmetic / perfumes / bath / nail preparations ...    58502    57799    55158
# Electric appliances for personal care                 10057     9963    10223
# Tobacco                                               74734    74105    74144
#
#                                                     2020M04  2020M05  2020M06  \
# Consumption Category
# Gasoline and other motor fuel                        258098   312138   352503
# Lubricants and fluids                                  4743     5721     6446
# Fuel oil                                              27167    30496    27746
# Other fuels                                            1361     1418     1388
# Prescription drugs                                   392311   396323   404648
# Nonprescription drugs                                 76229    79927    82875
# Other medical products                                 5233     5800     6284
# Household cleaning products                           40557    42437    42594
# Household paper products                              37601    39052    39452
# Household linens                                      42161    51225    54864
# Sewing items                                           1490     2008     2337
# Miscellaneous household products                      28790    30868    30593
# Hair dental shaving and miscellaneous personal ...    73333    77951    81100
# Cosmetic / perfumes / bath / nail preparations ...    47674    54279    57943
# Electric appliances for personal care                  9608    10812    11225
# Tobacco                                               75486    76160    76651
#
#                                                     2020M07  2020M08  2020M09
# Consumption Category
# Gasoline and other motor fuel                        363811   369140   374007
# Lubricants and fluids                                  6656     6742     6831
# Fuel oil                                              26913    26182    28497
# Other fuels                                            1398     1425     1479
# Prescription drugs                                   408873   412429   417457
# Nonprescription drugs                                 85731    84330    84740
# Other medical products                                 6791     6945     7151
# Household cleaning products                           41637    41494    41810
# Household paper products                              37998    37965    39656
# Household linens                                      56319    56326    56894
# Sewing items                                           2223     1904     2040
# Miscellaneous household products                      30667    30730    31106
# Hair dental shaving and miscellaneous personal ...    82083    81309    82306
# Cosmetic / perfumes / bath / nail preparations ...    60614    60911    62634
# Electric appliances for personal care                 11176    11119    11249
# Tobacco                                               76431    76224    75988

# %%
graph15_df = graph_necessities_df[['2015M01', '2015M02', '2015M03', '2015M04',
       '2015M05', '2015M06', '2015M07', '2015M08', '2015M09']]
months = graph15_df.keys()
months = ["Jan","Feb","March","April","May","June","July","August","Sept"]

graph16_df = graph_necessities_df[['2016M01', '2016M02', '2016M03', '2016M04',
       '2016M05', '2016M06', '2016M07', '2016M08', '2016M09']]
months = graph16_df.keys()
months = ["Jan","Feb","March","April","May","June","July","August","Sept"]

graph17_df = graph_necessities_df[['2017M01', '2017M02', '2017M03', '2017M04',
       '2017M05', '2017M06', '2017M07', '2017M08', '2017M09']]
months = graph17_df.keys()
months = ["Jan","Feb","March","April","May","June","July","August","Sept"]

graph18_df = graph_necessities_df[['2018M01', '2018M02', '2018M03', '2018M04',
        '2018M05', '2018M06', '2018M07', '2018M08', '2018M09']]
months = graph18_df.keys()
months = ["Jan","Feb","March","April","May","June","July","August","Sept"]

graph19_df = graph_necessities_df[['2019M01', '2019M02', '2019M03', '2019M04',
        '2019M05', '2019M06', '2019M07', '2019M08', '2019M09']]
months = graph19_df.keys()
months = ["Jan","Feb","March","April","May","June","July","August","Sept"]

graph20_df = graph_necessities20[['2020M01', '2020M02', '2020M03', '2020M04',
       '2020M05', '2020M06', '2020M07', '2020M08', '2020M09']]
months = graph20_df.keys()
months = ["Jan","Feb","March","April","May","June","July","August","Sept"]

# %%
# 2015-2020 (Jan-Sept) Cleaning Product Consumption Comparison

cleaningproduct15 = plt.plot(months, graph15_df.loc['Household cleaning products', :], color="orange", label="2015")

cleaningproduct16 = plt.plot(months, graph16_df.loc['Household cleaning products', :], color="pink", label="2016")

cleaningproduct17 = plt.plot(months, graph17_df.loc['Household cleaning products', :], color="green", label="2017")

cleaningproduct18 = plt.plot(months, graph18_df.loc['Household cleaning products', :], color="yellow", label="2018")

cleaningproduct19 = plt.plot(months, graph19_df.loc['Household cleaning products', :], color="blue", label="2019")

cleaningproduct20 = plt.plot(months, graph20_df.loc['Household cleaning products', :], color="red", label="2020")

plt.legend([2015, 2016, 2017, 2018, 2019, 2020], loc="best")
plt.title("2015-2020 Cleaning Product Consumption (Jan-Sept)")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.savefig('Images/CleaningProducts2015-2020')
plt.show()

# %%
# 2015-2020 (Jan-Sept) Gasoline & Motor Fuel Consumption Comparison

gasoline15 = plt.plot(months, graph15_df.loc['Gasoline and other motor fuel', :], color="orange", label="2015")

gasoline16 = plt.plot(months, graph16_df.loc['Gasoline and other motor fuel', :], color="pink", label="2016")

gasoline17 = plt.plot(months, graph17_df.loc['Gasoline and other motor fuel', :], color="green", label="2017")

gasoline18 = plt.plot(months, graph18_df.loc['Gasoline and other motor fuel', :], color="yellow", label="2018")

gasoline19 = plt.plot(months, graph19_df.loc['Gasoline and other motor fuel', :], color="blue", label="2019")

gasoline20 = plt.plot(months, graph20_df.loc['Gasoline and other motor fuel', :], color="red", label="2019")

plt.legend([2015, 2016, 2017, 2018, 2019, 2020], loc="best")
plt.title("2015-2020 Gasoline & Motor Fuel Consumption (Jan-Sept)")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.savefig('Images/Gasoline2015-2020')
plt.show()

# %%
# 2015-2020 (Jan-Sept) Prescription Drug Consumption Comparison

prescription15 = plt.plot(months, graph15_df.loc['Prescription drugs', :], color="orange", label="2015")

prescription16 = plt.plot(months, graph16_df.loc['Prescription drugs', :], color="pink", label="2016")

prescription17 = plt.plot(months, graph17_df.loc['Prescription drugs', :], color="green", label="2017")

prescription18 = plt.plot(months, graph18_df.loc['Prescription drugs', :], color="yellow", label="2018")

prescription19 = plt.plot(months, graph19_df.loc['Prescription drugs', :], color="blue", label="2019")

preceiption20 = plt.plot(months, graph20_df.loc['Prescription drugs', :], color="red", label="2019")

plt.legend([2015, 2016, 2017, 2018, 2019, 2020], loc="best")
plt.title("2015-2020 Prescription Drug Consumption (Jan-Sept)")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.savefig('Images/Precriptions2015-2020')
plt.show()

# %%
# 2015-2020 (Jan-Sept) Nonprescription Drug Consumption Comparison

nonprescription15 = plt.plot(months, graph15_df.loc['Nonprescription drugs', :], color="orange", label="2015")

nonprescription16 = plt.plot(months, graph16_df.loc['Nonprescription drugs', :], color="pink", label="2016")

nonprescription17 = plt.plot(months, graph17_df.loc['Nonprescription drugs', :], color="green", label="2017")

nonprescription18 = plt.plot(months, graph18_df.loc['Nonprescription drugs', :], color="yellow", label="2018")

nonprescription19 = plt.plot(months, graph19_df.loc['Nonprescription drugs', :], color="blue", label="2019")

nonpreceiption20 = plt.plot(months, graph20_df.loc['Nonprescription drugs', :], color="red", label="2019")

plt.legend([2015, 2016, 2017, 2018, 2019, 2020], loc="best")
plt.title("2015-2020 Nonprescription Drug Consumption (Jan-Sept)")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.savefig('Images/NonPrescription2015-2020')
plt.show()

# %%
# 2015-2020 (Jan-Sept) Other Medical Products Consumption Comparison

othermed15 = plt.plot(months, graph15_df.loc['Other medical products', :], color="orange", label="2015")

othermed16 = plt.plot(months, graph16_df.loc['Other medical products', :], color="pink", label="2016")

othermed17 = plt.plot(months, graph17_df.loc['Other medical products', :], color="green", label="2017")

othermed18 = plt.plot(months, graph18_df.loc['Other medical products', :], color="yellow", label="2018")

othermed19 = plt.plot(months, graph19_df.loc['Other medical products', :], color="blue", label="2019")

othermed20 = plt.plot(months, graph20_df.loc['Other medical products', :], color="red", label="2019")

plt.legend([2015, 2016, 2017, 2018, 2019, 2020], loc="best")
plt.title("2015-2020 Other Medical Product Consumption (Jan-Sept)")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.show()

# %%
# 2015-2020 (Jan-Sept) Household Paper Product Consumption Comparison

paper15 = plt.plot(months, graph15_df.loc['Household paper products', :], color="orange", label="2015")

paper16 = plt.plot(months, graph16_df.loc['Household paper products', :], color="pink", label="2016")

paper17 = plt.plot(months, graph17_df.loc['Household paper products', :], color="green", label="2017")

paper18 = plt.plot(months, graph18_df.loc['Household paper products', :], color="yellow", label="2018")

paper19 = plt.plot(months, graph19_df.loc['Household paper products', :], color="blue", label="2019")

paper20 = plt.plot(months, graph20_df.loc['Household paper products', :], color="red", label="2019")

plt.legend([2015, 2016, 2017, 2018, 2019, 2020], loc="best")
plt.title("2015-2020 Household Paper Product Consumption (Jan-Sept)")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.savefig('Images/PaperProducts2015-2020')
plt.show()

# %%
# 2019 vs. 2020 Nondurable Goods Analysis

# %%
# necessity items

necessities = pd.read_csv('Resources/necessityitems_consumption_19_20.csv')
necessities
# Out:
#                                 Consumption Category   2019M01  2019M02  \
# 0                       Gasoline and other motor fuel   416232   413890
# 1                               Lubricants and fluids     7617     7591
# 2                                            Fuel oil    24220    23751
# 3                                         Other fuels     1614     1628
# 4                                  Prescription drugs   376230   383557
# 5                               Nonprescription drugs    76356    76578
# 6                              Other medical products     6348     6393
# 7                         Household cleaning products    39808    39000
# 8                            Household paper products    38486    38043
# 9                                    Household linens    50275    52134
# 10                                       Sewing items     1777     1744
# 11                   Miscellaneous household products    22977    23197
# 12  Hair dental shaving and miscellaneous personal...    76378    76206
# 13  Cosmetic / perfumes / bath / nail preparations...    55225    55691
# 14              Electric appliances for personal care     9649     9681
#
#     2019M03  2019M04  2019M05  2019M06  2019M07  2019M08  2019M09  ...  \
# 0    411127   419375   411998   413314   410698   417331   411279  ...
# 1      7545     7660     7535     7555     7506     7612     7489  ...
# 2     24371    23015    22774    23604    23258    23221    22515  ...
# 3      1677     1610     1589     1638     1621     1618     1587  ...
# 4    386897   381678   386486   390877   392962   396058   397687  ...
# 5     76869    76924    77264    77546    77802    76594    77062  ...
# 6      6504     6409     6423     6428     6545     6531     6584  ...
# 7     39233    39404    39403    39517    39833    39976    39676  ...
# 8     37969    38330    38133    38033    38614    38772    38374  ...
# 9     52048    53455    53907    55545    55025    54317    53697  ...
# 10     1689     1762     1810     1785     1764     1827     1843  ...
# 11    23177    23666    24610    24898    24911    25455    25403  ...
# 12    77109    76955    77276    77755    77542    77648    77703  ...
# 13    56000    56205    57360    57518    57244    56709    56859  ...
# 14     9748     9809     9887     9969     9963    10017     9998  ...
#
#     2019M12  2020M01  2020M02  2020M03  2020M04  2020M05  2020M06  2020M07  \
# 0    403003   414196   412515   348239   258098   312138   352503   363811
# 1      7358     7555     7541     6383     4743     5721     6446     6656
# 2     21250    19725    21692    23366    27167    30496    27746    26913
# 3      1497     1428     1438     1347     1361     1418     1388     1398
# 4    393525   397892   404197   429613   392311   396323   404648   408873
# 5     77449    78626    79126    85388    76229    79927    82875    85731
# 6      6523     6612     6614     6215     5233     5800     6284     6791
# 7     39571    39791    40017    46227    40557    42437    42594    41637
# 8     37652    38042    37937    44706    37601    39052    39452    37998
# 9     56232    53555    52812    50236    42161    51225    54864    56319
# 10     1838     1836     1834     1755     1490     2008     2337     2223
# 11    25447    25758    26018    27188    28790    30868    30593    30667
# 12    77037    77612    76724    83456    73333    77951    81100    82083
# 13    58299    58502    57799    55158    47674    54279    57943    60614
# 14     9883    10057     9963    10223     9608    10812    11225    11176
#
#     2020M08  2020M09
# 0    369140   374007
# 1      6742     6831
# 2     26182    28497
# 3      1425     1479
# 4    412429   417457
# 5     84330    84740
# 6      6945     7151
# 7     41494    41810
# 8     37965    39656
# 9     56326    56894
# 10     1904     2040
# 11    30730    31106
# 12    81309    82306
# 13    60911    62634
# 14    11119    11249
#
# [15 rows x 22 columns]

# %%
necessities19 = necessities.loc[:, ['Consumption Category ', '2019M01', '2019M02', '2019M03', '2019M04', '2019M05', '2019M06', '2019M07', '2019M08', '2019M09']]
necessities19.dtypes

necessities20 = necessities.loc[:, ['Consumption Category ', '2020M01', '2020M02', '2020M03', '2020M04', '2020M05', '2020M06', '2020M07', '2020M08', '2020M09']]
necessities20.dtypes

necessities.describe()
# Out:
#              2019M01        2019M02        2019M03       2019M04  \
# count      15.000000      15.000000      15.000000      15.00000
# mean    80212.800000   80605.600000   80797.533333   81083.80000
# std    130904.951081  131670.947307  131692.993362  132315.60156
# min      1614.000000    1628.000000    1677.000000    1610.00000
# 25%      8633.000000    8636.000000    8646.500000    8734.50000
# 50%     38486.000000   38043.000000   37969.000000   38330.00000
# 75%     65790.500000   65948.500000   66434.500000   66564.50000
# max    416232.000000  413890.000000  411127.000000  419375.00000
#
#              2019M05        2019M06        2019M07        2019M08  \
# count      15.000000      15.000000      15.000000      15.000000
# mean    81097.000000   81732.133333   81685.866667   82245.733333
# std    131728.341512  132625.349323  132508.001569  134195.807401
# min      1589.000000    1638.000000    1621.000000    1618.000000
# 25%      8711.000000    8762.000000    8734.500000    8814.500000
# 50%     38133.000000   38033.000000   38614.000000   38772.000000
# 75%     67312.000000   67532.000000   67393.000000   66651.500000
# max    411998.000000  413314.000000  410698.000000  417331.000000
#
#              2019M09        2019M10  ...        2019M12        2020M01  \
# count      15.000000      15.000000  ...      15.000000      15.000000
# mean    81850.400000   82144.533333  ...   81104.266667   82079.133333
# std    133446.073575  133895.057828  ...  131306.974802  134059.772951
# min      1587.000000    1565.000000  ...    1497.000000    1428.000000
# 25%      8743.500000    8776.500000  ...    8620.500000    8806.000000
# 50%     38374.000000   38328.000000  ...   37652.000000   38042.000000
# 75%     66960.500000   67494.500000  ...   67668.000000   68057.000000
# max    411279.000000  417060.000000  ...  403003.000000  414196.000000
#
#              2020M02        2020M03        2020M04        2020M05  \
# count      15.000000      15.000000      15.000000      15.000000
# mean    82415.133333   81300.000000   69757.066667   76030.333333
# std    134783.083585  128764.443953  109395.287332  116871.688144
# min      1438.000000    1347.000000    1361.000000    1418.000000
# 25%      8752.000000    8303.000000    7420.500000    8306.000000
# 50%     37937.000000   44706.000000   37601.000000   39052.000000
# 75%     67261.500000   69307.000000   60503.500000   66115.000000
# max    412515.000000  429613.000000  392311.000000  396323.000000
#
#              2020M06        2020M07        2020M08        2020M09
# count      15.000000      15.000000      15.000000      15.000000
# mean    80133.200000   81526.000000   81930.066667   83190.466667
# std    124436.517884  127008.446028  128534.417774  130051.608505
# min      1388.000000    1398.000000    1425.000000    1479.000000
# 25%      8835.500000    8983.500000    9032.000000    9200.000000
# 50%     39452.000000   37998.000000   37965.000000   39656.000000
# 75%     69521.500000   71348.500000   71110.000000   72470.000000
# max    404648.000000  408873.000000  412429.000000  417457.000000
#
# [8 rows x 21 columns]

# %%
totalNecessities19 = necessities19.sum(axis=1)
necessities19['Total'] = totalNecessities19
necessities19
# Out:
#                                 Consumption Category   2019M01  2019M02  \
# 0                       Gasoline and other motor fuel   416232   413890
# 1                               Lubricants and fluids     7617     7591
# 2                                            Fuel oil    24220    23751
# 3                                         Other fuels     1614     1628
# 4                                  Prescription drugs   376230   383557
# 5                               Nonprescription drugs    76356    76578
# 6                              Other medical products     6348     6393
# 7                         Household cleaning products    39808    39000
# 8                            Household paper products    38486    38043
# 9                                    Household linens    50275    52134
# 10                                       Sewing items     1777     1744
# 11                   Miscellaneous household products    22977    23197
# 12  Hair dental shaving and miscellaneous personal...    76378    76206
# 13  Cosmetic / perfumes / bath / nail preparations...    55225    55691
# 14              Electric appliances for personal care     9649     9681
#
#     2019M03  2019M04  2019M05  2019M06  2019M07  2019M08  2019M09    Total
# 0    411127   419375   411998   413314   410698   417331   411279  3725244
# 1      7545     7660     7535     7555     7506     7612     7489    68110
# 2     24371    23015    22774    23604    23258    23221    22515   210729
# 3      1677     1610     1589     1638     1621     1618     1587    14582
# 4    386897   381678   386486   390877   392962   396058   397687  3492432
# 5     76869    76924    77264    77546    77802    76594    77062   692995
# 6      6504     6409     6423     6428     6545     6531     6584    58165
# 7     39233    39404    39403    39517    39833    39976    39676   355850
# 8     37969    38330    38133    38033    38614    38772    38374   344754
# 9     52048    53455    53907    55545    55025    54317    53697   480403
# 10     1689     1762     1810     1785     1764     1827     1843    16001
# 11    23177    23666    24610    24898    24911    25455    25403   218294
# 12    77109    76955    77276    77755    77542    77648    77703   694572
# 13    56000    56205    57360    57518    57244    56709    56859   508811
# 14     9748     9809     9887     9969     9963    10017     9998    88721

# %%
totalNecessities20 = necessities20.sum(axis=1)
necessities20['Total'] = totalNecessities20
necessities20
# Out:
#                                 Consumption Category   2020M01  2020M02  \
# 0                       Gasoline and other motor fuel   414196   412515
# 1                               Lubricants and fluids     7555     7541
# 2                                            Fuel oil    19725    21692
# 3                                         Other fuels     1428     1438
# 4                                  Prescription drugs   397892   404197
# 5                               Nonprescription drugs    78626    79126
# 6                              Other medical products     6612     6614
# 7                         Household cleaning products    39791    40017
# 8                            Household paper products    38042    37937
# 9                                    Household linens    53555    52812
# 10                                       Sewing items     1836     1834
# 11                   Miscellaneous household products    25758    26018
# 12  Hair dental shaving and miscellaneous personal...    77612    76724
# 13  Cosmetic / perfumes / bath / nail preparations...    58502    57799
# 14              Electric appliances for personal care    10057     9963
#
#     2020M03  2020M04  2020M05  2020M06  2020M07  2020M08  2020M09    Total
# 0    348239   258098   312138   352503   363811   369140   374007  3204647
# 1      6383     4743     5721     6446     6656     6742     6831    58618
# 2     23366    27167    30496    27746    26913    26182    28497   231784
# 3      1347     1361     1418     1388     1398     1425     1479    12682
# 4    429613   392311   396323   404648   408873   412429   417457  3663743
# 5     85388    76229    79927    82875    85731    84330    84740   736972
# 6      6215     5233     5800     6284     6791     6945     7151    57645
# 7     46227    40557    42437    42594    41637    41494    41810   376564
# 8     44706    37601    39052    39452    37998    37965    39656   352409
# 9     50236    42161    51225    54864    56319    56326    56894   474392
# 10     1755     1490     2008     2337     2223     1904     2040    17427
# 11    27188    28790    30868    30593    30667    30730    31106   261718
# 12    83456    73333    77951    81100    82083    81309    82306   715874
# 13    55158    47674    54279    57943    60614    60911    62634   515514
# 14    10223     9608    10812    11225    11176    11119    11249    95432

# %%
necessityYearTotals = pd.DataFrame({
    'Category': necessities19['Consumption Category '],
    '2019': totalNecessities19,
    '2020': totalNecessities20
    
})
necessityYearTotals = necessityYearTotals['Category'].str.lstrip()

# %%
# Month Over Month Comparison 

mom_data = necessities.loc[:, ['Consumption Category ', 
        '2019M01', '2019M02', '2019M03', '2019M04','2019M05', '2019M06', '2019M07', '2019M08', '2019M09',
        '2020M01', '2020M02', '2020M03', '2020M04','2020M05', '2020M06', '2020M07', '2020M08', '2020M09']]
mom_data = mom_data.set_index('Consumption Category ')

mom19 = mom_data.loc[['Gasoline and other motor fuel','Prescription drugs',
                      'Nonprescription drugs','Other medical products','Household cleaning products',
                    'Household paper products'],['2019M01', '2019M02', '2019M03', '2019M04','2019M05',
                    '2019M06', '2019M07', '2019M08', '2019M09']]

mom19

mom20 = mom_data.loc[['Gasoline and other motor fuel','Prescription drugs',
                      'Nonprescription drugs','Other medical products','Household cleaning products',
                    'Household paper products'],['2020M01', '2020M02', '2020M03', '2020M04','2020M05',
                    '2020M06', '2020M07', '2020M08', '2020M09']]

mom20
# Out:
#                                2020M01  2020M02  2020M03  2020M04  2020M05  \
# Consumption Category
# Gasoline and other motor fuel   414196   412515   348239   258098   312138
# Prescription drugs              397892   404197   429613   392311   396323
# Nonprescription drugs            78626    79126    85388    76229    79927
# Other medical products            6612     6614     6215     5233     5800
# Household cleaning products      39791    40017    46227    40557    42437
# Household paper products         38042    37937    44706    37601    39052
#
#                                2020M06  2020M07  2020M08  2020M09
# Consumption Category
# Gasoline and other motor fuel   352503   363811   369140   374007
# Prescription drugs              404648   408873   412429   417457
# Nonprescription drugs            82875    85731    84330    84740
# Other medical products            6284     6791     6945     7151
# Household cleaning products      42594    41637    41494    41810
# Household paper products         39452    37998    37965    39656

# %%
# 2019 vs. 2020 Cleaning Product Consumption
cleaningproduct19 = plt.plot(months, graph19_df.loc['Household cleaning products',['2019M01', '2019M02', '2019M03', '2019M04', '2019M05', '2019M06',
       '2019M07', '2019M08', '2019M09']], color="blue", label="2019")

cleaningproduct20 = plt.plot(months, graph20_df.loc['Household cleaning products',['2020M01', '2020M02', '2020M03', '2020M04', '2020M05', '2020M06',
       '2020M07', '2020M08', '2020M09']], color="red", label="2020")

plt.legend([2019, 2020], loc="best")
plt.title("2019 vs. 2020 Cleaning Product Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.savefig('Images/cleaningproducts19vs20.png')
plt.show()

# %%
# CLEANING PRODUCTS MONTH OVER MONTH

mom19_cleaning = mom19.loc[['Household cleaning products'],['2019M01', '2019M02', '2019M03', '2019M04','2019M05',
                    '2019M06', '2019M07', '2019M08', '2019M09']]
mom19_cleaning


mom20_cleaning = mom20.loc[['Household cleaning products'],['2020M01', '2020M02', '2020M03', '2020M04','2020M05',
                    '2020M06', '2020M07', '2020M08', '2020M09']]
mom20_cleaning


cleaning19_df = pd.DataFrame({
    'January': mom19_cleaning['2019M01'],
    'February': mom19_cleaning['2019M02'],
    'March': mom19_cleaning['2019M03'],
    'April': mom19_cleaning['2019M04'],
    'May': mom19_cleaning['2019M05'],
    'June': mom19_cleaning['2019M06'],
    'July': mom19_cleaning['2019M07'],
    'August': mom19_cleaning['2019M08'],
    'September': mom19_cleaning['2019M09']
    
})

cleaning19_df = cleaning19_df.rename(index={'Household cleaning products':'2019 Household Cleaning Products'})

cleaning20_df = pd.DataFrame({
    'January': mom20_cleaning['2020M01'],
    'February': mom20_cleaning['2020M02'],
    'March': mom20_cleaning['2020M03'],
    'April': mom20_cleaning['2020M04'],
    'May': mom20_cleaning['2020M05'],
    'June': mom20_cleaning['2020M06'],
    'July': mom20_cleaning['2020M07'],
    'August': mom20_cleaning['2020M08'],
    'September': mom20_cleaning['2020M09']
    
})
cleaning20_df = cleaning20_df.rename(index={'Household cleaning products':'2020 Household Cleaning Products'})

cleaning19_df
cleaning20_df

cleaning_df = pd.DataFrame({
    'January': mom20_cleaning['2020M01'],
    'February': mom20_cleaning['2020M02'],
    'March': mom20_cleaning['2020M03'],
    'April': mom20_cleaning['2020M04'],
    'May': mom20_cleaning['2020M05'],
    'June': mom20_cleaning['2020M06'],
    'July': mom20_cleaning['2020M07'],
    'August': mom20_cleaning['2020M08'],
    'September': mom20_cleaning['2020M09']
})

cleaning_df = cleaning19_df.merge(cleaning20_df, on=('Consumption Category ','January','February','March','April','May','June','July',
                    'August','September'), how='outer')

cleaning_df = cleaning_df.transpose()
cleaning_df['Percent Change'] = ""
cleaning_df
# Out:
# Consumption Category   2019 Household Cleaning Products  \
# January                                           39808
# February                                          39000
# March                                             39233
# April                                             39404
# May                                               39403
# June                                              39517
# July                                              39833
# August                                            39976
# September                                         39676
#
# Consumption Category   2020 Household Cleaning Products Percent Change
# January                                           39791
# February                                          40017
# March                                             46227
# April                                             40557
# May                                               42437
# June                                              42594
# July                                              41637
# August                                            41494
# September                                         41810

# %%
# 2019-2020 Percent Change by Month

cleaning_df.apply(lambda row: (row.iloc[1]-row.iloc[0])/row.iloc[0]*100, axis=1)
# Out:
# January      -0.042705
# February      2.607692
# March        17.826829
# April         2.926099
# May           7.699921
# June          7.786522
# July          4.528908
# August        3.797278
# September     5.378566
# dtype: float64

# %%
# 2019 vs. 2020 Other Medical Product Consumption
othermedicalproduct19 = plt.plot(months, graph19_df.loc['Other medical products',['2019M01', '2019M02', '2019M03', '2019M04', '2019M05', '2019M06',
       '2019M07', '2019M08', '2019M09']], color="blue", label="2019")

othermedicalproduct20 = plt.plot(months, graph20_df.loc['Other medical products',['2020M01', '2020M02', '2020M03', '2020M04', '2020M05', '2020M06',
       '2020M07', '2020M08', '2020M09']], color="red", label="2020")

plt.legend([2019, 2020], loc="best")
plt.title("2019 vs. 2020 Other Medical Product Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.savefig('Images/othermedical19vs20.png')
plt.show()

# %%
# 2019 vs. 2020 Nonprescription Drug Consumption
nonpresceiptiondrugs19 = plt.plot(months, graph19_df.loc['Nonprescription drugs',['2019M01', '2019M02', '2019M03', '2019M04', '2019M05', '2019M06',
       '2019M07', '2019M08', '2019M09']], color="blue", label="2019")

nonprescriptiondrugs20 = plt.plot(months, graph20_df.loc['Nonprescription drugs',['2020M01', '2020M02', '2020M03', '2020M04', '2020M05', '2020M06',
       '2020M07', '2020M08', '2020M09']], color="red", label="2020")

plt.legend([2019, 2020], loc="best")
plt.title("2019 vs. 2020 Nonprescription Drug Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.savefig('Images/nonprescription19vs20.png')
plt.show()

# %%
# NONPRESCRIPTION DRUGS MONTH OVER MONTH


mom19_nonprescription = mom19.loc[['Nonprescription drugs'],['2019M01', '2019M02', '2019M03', '2019M04','2019M05',
                    '2019M06', '2019M07', '2019M08', '2019M09']]
mom19_nonprescription


mom20_nonprescription = mom20.loc[['Nonprescription drugs'],['2020M01', '2020M02', '2020M03', '2020M04','2020M05',
                    '2020M06', '2020M07', '2020M08', '2020M09']]
mom20_nonprescription


nonprescription19_df = pd.DataFrame({
    'January': mom19_nonprescription['2019M01'],
    'February': mom19_nonprescription['2019M02'],
    'March': mom19_nonprescription['2019M03'],
    'April': mom19_nonprescription['2019M04'],
    'May': mom19_nonprescription['2019M05'],
    'June': mom19_nonprescription['2019M06'],
    'July': mom19_nonprescription['2019M07'],
    'August': mom19_nonprescription['2019M08'],
    'September': mom19_nonprescription['2019M09']
    
})

nonprescription19_df = nonprescription19_df.rename(index={'Nonprescription drugs':'2019 Nonprescription Drugs'})

nonprescription20_df = pd.DataFrame({
    'January': mom20_nonprescription['2020M01'],
    'February': mom20_nonprescription['2020M02'],
    'March': mom20_nonprescription['2020M03'],
    'April': mom20_nonprescription['2020M04'],
    'May': mom20_nonprescription['2020M05'],
    'June': mom20_nonprescription['2020M06'],
    'July': mom20_nonprescription['2020M07'],
    'August': mom20_nonprescription['2020M08'],
    'September': mom20_nonprescription['2020M09']
    
})
nonprescription20_df = nonprescription20_df.rename(index={'Nonprescription drugs':'2020 Nonprescription Drugs'})

nonprescription_df = pd.DataFrame({
    'January': mom20_nonprescription['2020M01'],
    'February': mom20_nonprescription['2020M02'],
    'March': mom20_nonprescription['2020M03'],
    'April': mom20_nonprescription['2020M04'],
    'May': mom20_nonprescription['2020M05'],
    'June': mom20_nonprescription['2020M06'],
    'July': mom20_nonprescription['2020M07'],
    'August': mom20_nonprescription['2020M08'],
    'September': mom20_nonprescription['2020M09']
})

nonprescription_df = nonprescription19_df.merge(nonprescription20_df, on=('Consumption Category ','January','February','March','April','May','June','July',
                    'August','September'), how='outer')

nonprescription_df = nonprescription_df.transpose()

nonprescription_df
# Out:
# Consumption Category   2019 Nonprescription Drugs  2020 Nonprescription Drugs
# January                                     76356                       78626
# February                                    76578                       79126
# March                                       76869                       85388
# April                                       76924                       76229
# May                                         77264                       79927
# June                                        77546                       82875
# July                                        77802                       85731
# August                                      76594                       84330
# September                                   77062                       84740

# %%
# 2019-2020 Percent Change by Month
nonprescription_df.apply(lambda row: (row.iloc[1]-row.iloc[0])/row.iloc[0]*100, axis=1)
# Out:
# January       2.972916
# February      3.327326
# March        11.082491
# April        -0.903489
# May           3.446625
# June          6.872050
# July         10.191255
# August       10.100008
# September     9.963406
# dtype: float64

# %%
# 2019 vs. 2020 Prescription Drug Consumption
presceiptiondrugs19 = plt.plot(months, graph19_df.loc['Prescription drugs',['2019M01', '2019M02', '2019M03', '2019M04', '2019M05', '2019M06',
       '2019M07', '2019M08', '2019M09']], color="blue", label="2019")

prescriptiondrugs20 = plt.plot(months, graph20_df.loc['Prescription drugs',['2020M01', '2020M02', '2020M03', '2020M04', '2020M05', '2020M06',
       '2020M07', '2020M08', '2020M09']], color="red", label="2020")

plt.legend([2019, 2020], loc="best")
plt.title("2019 vs. 2020 Prescription Drug Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.savefig('Images/prescriptiondrugs19vs20.png')
plt.show()

# %%
# PRESCRIPTION DRUGS MONTH OVER MONTH


mom19_prescription = mom19.loc[['Prescription drugs'],['2019M01', '2019M02', '2019M03', '2019M04','2019M05',
                    '2019M06', '2019M07', '2019M08', '2019M09']]
mom19_prescription


mom20_prescription = mom20.loc[['Prescription drugs'],['2020M01', '2020M02', '2020M03', '2020M04','2020M05',
                    '2020M06', '2020M07', '2020M08', '2020M09']]
mom20_prescription


prescription19_df = pd.DataFrame({
    'January': mom19_prescription['2019M01'],
    'February': mom19_prescription['2019M02'],
    'March': mom19_prescription['2019M03'],
    'April': mom19_prescription['2019M04'],
    'May': mom19_prescription['2019M05'],
    'June': mom19_prescription['2019M06'],
    'July': mom19_prescription['2019M07'],
    'August': mom19_prescription['2019M08'],
    'September': mom19_prescription['2019M09']
    
})

prescription19_df = prescription19_df.rename(index={'Prescription drugs':'2019 Prescription Drugs'})

prescription20_df = pd.DataFrame({
    'January': mom20_prescription['2020M01'],
    'February': mom20_prescription['2020M02'],
    'March': mom20_prescription['2020M03'],
    'April': mom20_prescription['2020M04'],
    'May': mom20_prescription['2020M05'],
    'June': mom20_prescription['2020M06'],
    'July': mom20_prescription['2020M07'],
    'August': mom20_prescription['2020M08'],
    'September': mom20_prescription['2020M09']
    
})
prescription20_df = prescription20_df.rename(index={'Prescription drugs':'2020 Prescription Drugs'})

prescription19_df
prescription20_df

prescription_df = pd.DataFrame({
    'January': mom20_prescription['2020M01'],
    'February': mom20_prescription['2020M02'],
    'March': mom20_prescription['2020M03'],
    'April': mom20_prescription['2020M04'],
    'May': mom20_prescription['2020M05'],
    'June': mom20_prescription['2020M06'],
    'July': mom20_prescription['2020M07'],
    'August': mom20_prescription['2020M08'],
    'September': mom20_prescription['2020M09']
})

prescription_df = prescription19_df.merge(prescription20_df, on=('Consumption Category ','January','February','March','April','May','June','July',
                    'August','September'), how='outer')

prescription_df = prescription_df.transpose()

prescription_df['Percent Change'] = ""
prescription_df
# Out:
# Consumption Category   2019 Prescription Drugs  2020 Prescription Drugs  \
# January                                 376230                   397892
# February                                383557                   404197
# March                                   386897                   429613
# April                                   381678                   392311
# May                                     386486                   396323
# June                                    390877                   404648
# July                                    392962                   408873
# August                                  396058                   412429
# September                               397687                   417457
#
# Consumption Category  Percent Change
# January
# February
# March
# April
# May
# June
# July
# August
# September

# %%
# 2019-2020 Percent Change by Month
prescription_df.apply(lambda row: (row.iloc[1]-row.iloc[0])/row.iloc[0]*100, axis=1)
# Out:
# January       5.757648
# February      5.381208
# March        11.040665
# April         2.785856
# May           2.545241
# June          3.523103
# July          4.048992
# August        4.133485
# September     4.971246
# dtype: float64

# %%
# 2019 vs. 2020 Gasoline & Motor Fuel Consumption
gasoline19 = plt.plot(months, graph19_df.loc['Gasoline and other motor fuel',['2019M01', '2019M02', '2019M03', '2019M04', '2019M05', '2019M06',
       '2019M07', '2019M08', '2019M09']], color="blue", label="2019")

gasoline20 = plt.plot(months, graph20_df.loc['Gasoline and other motor fuel',['2020M01', '2020M02', '2020M03', '2020M04', '2020M05', '2020M06',
       '2020M07', '2020M08', '2020M09']], color="red", label="2020")

plt.legend([2019, 2020], loc="best")
plt.title("2019 vs. 2020 Gasoline & Motor Fuel Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.savefig('Images/gasoline19vs20.png')
plt.show()

# %%
# GASOLINE MONTH OVER MONTH

mom19_gasoline = mom19.loc[['Gasoline and other motor fuel'],['2019M01', '2019M02', '2019M03', '2019M04','2019M05',
                    '2019M06', '2019M07', '2019M08', '2019M09']]
mom19_gasoline


mom20_gasoline = mom20.loc[['Gasoline and other motor fuel'],['2020M01', '2020M02', '2020M03', '2020M04','2020M05',
                    '2020M06', '2020M07', '2020M08', '2020M09']]
mom20_gasoline

gasoline19_df = pd.DataFrame({
    'January': mom19_gasoline['2019M01'],
    'February': mom19_gasoline['2019M02'],
    'March': mom19_gasoline['2019M03'],
    'April': mom19_gasoline['2019M04'],
    'May': mom19_gasoline['2019M05'],
    'June': mom19_gasoline['2019M06'],
    'July': mom19_gasoline['2019M07'],
    'August': mom19_gasoline['2019M08'],
    'September': mom19_gasoline['2019M09']
    
})

gasoline19_df = gasoline19_df.rename(index={'Gasoline and other motor fuel':'2019 Gasoline and Motor Fuel'})

gasoline20_df = pd.DataFrame({
    'January': mom20_gasoline['2020M01'],
    'February': mom20_gasoline['2020M02'],
    'March': mom20_gasoline['2020M03'],
    'April': mom20_gasoline['2020M04'],
    'May': mom20_gasoline['2020M05'],
    'June': mom20_gasoline['2020M06'],
    'July': mom20_gasoline['2020M07'],
    'August': mom20_gasoline['2020M08'],
    'September': mom20_gasoline['2020M09']
    
})
gasoline20_df = gasoline20_df.rename(index={'Gasoline and other motor fuel':'2020 Gasoline and Motor Fuel'})

gasoline19_df
gasoline20_df

gasoline_df = pd.DataFrame({
    'January': mom20_gasoline['2020M01'],
    'February': mom20_gasoline['2020M02'],
    'March': mom20_gasoline['2020M03'],
    'April': mom20_gasoline['2020M04'],
    'May': mom20_gasoline['2020M05'],
    'June': mom20_gasoline['2020M06'],
    'July': mom20_gasoline['2020M07'],
    'August': mom20_gasoline['2020M08'],
    'September': mom20_gasoline['2020M09']
})

gasoline_df = gasoline19_df.merge(gasoline20_df, on=('Consumption Category ','January','February','March','April','May','June','July',
                    'August','September'), how='outer')

gasoline_df = gasoline_df.transpose()
gasoline_df['Percent Change'] = ""
gasoline_df
# Out:
# Consumption Category   2019 Gasoline and Motor Fuel  \
# January                                      416232
# February                                     413890
# March                                        411127
# April                                        419375
# May                                          411998
# June                                         413314
# July                                         410698
# August                                       417331
# September                                    411279
#
# Consumption Category   2020 Gasoline and Motor Fuel Percent Change
# January                                      414196
# February                                     412515
# March                                        348239
# April                                        258098
# May                                          312138
# June                                         352503
# July                                         363811
# August                                       369140
# September                                    374007

# %%
gasoline_df.apply(lambda row: (row.iloc[1]-row.iloc[0])/row.iloc[0]*100, axis=1)
# Out:
# January      -0.489150
# February     -0.332214
# March       -15.296490
# April       -38.456513
# May         -24.237982
# June        -14.713027
# July        -11.416418
# August      -11.547429
# September    -9.062461
# dtype: float64

# %%
# 2019 vs. 2020 Household Paper Product Consumption
presceiptiondrugs19 = plt.plot(months, graph19_df.loc['Household paper products',['2019M01', '2019M02', '2019M03', '2019M04', '2019M05', '2019M06',
       '2019M07', '2019M08', '2019M09']], color="blue", label="2019")

prescriptiondrugs20 = plt.plot(months, graph20_df.loc['Household paper products',['2020M01', '2020M02', '2020M03', '2020M04', '2020M05', '2020M06',
       '2020M07', '2020M08', '2020M09']], color="red", label="2020")

plt.legend([2019, 2020], loc="best")
plt.title("2019 vs. 2020 Household Paper Product Consumption")
plt.xlabel("months")
plt.xticks(rotation="vertical")
plt.savefig('Images/paperproducts19vs20.png')
plt.show()

# %%
# HOUSEHOLD PAPER PRODUCTS MONTH OVER MONTH

mom19_paper = mom19.loc[['Household paper products'],['2019M01', '2019M02', '2019M03', '2019M04','2019M05',
                    '2019M06', '2019M07', '2019M08', '2019M09']]
mom19_paper


mom20_paper = mom20.loc[['Household paper products'],['2020M01', '2020M02', '2020M03', '2020M04','2020M05',
                    '2020M06', '2020M07', '2020M08', '2020M09']]
mom20_paper


paper19_df = pd.DataFrame({
    'January': mom19_paper['2019M01'],
    'February': mom19_paper['2019M02'],
    'March': mom19_paper['2019M03'],
    'April': mom19_paper['2019M04'],
    'May': mom19_paper['2019M05'],
    'June': mom19_paper['2019M06'],
    'July': mom19_paper['2019M07'],
    'August': mom19_paper['2019M08'],
    'September': mom19_paper['2019M09']
    
})

paper19_df = paper19_df.rename(index={'Household paper products':'2019 Household paper products'})

paper20_df = pd.DataFrame({
    'January': mom20_paper['2020M01'],
    'February': mom20_paper['2020M02'],
    'March': mom20_paper['2020M03'],
    'April': mom20_paper['2020M04'],
    'May': mom20_paper['2020M05'],
    'June': mom20_paper['2020M06'],
    'July': mom20_paper['2020M07'],
    'August': mom20_paper['2020M08'],
    'September': mom20_paper['2020M09']
    
})
paper20_df = paper20_df.rename(index={'Household paper products':'2020 Household paper products'})

paper19_df
paper20_df

paper_df = pd.DataFrame({
    'January': mom20_paper['2020M01'],
    'February': mom20_paper['2020M02'],
    'March': mom20_paper['2020M03'],
    'April': mom20_paper['2020M04'],
    'May': mom20_paper['2020M05'],
    'June': mom20_paper['2020M06'],
    'July': mom20_paper['2020M07'],
    'August': mom20_paper['2020M08'],
    'September': mom20_paper['2020M09']
})

paper_df = paper19_df.merge(paper20_df, on=('Consumption Category ','January','February','March','April','May','June','July',
                    'August','September'), how='outer')

paper_df = paper_df.transpose()

paper_df['Percent Change'] = ""
paper_df
# Out:
# Consumption Category   2019 Household paper products  \
# January                                        38486
# February                                       38043
# March                                          37969
# April                                          38330
# May                                            38133
# June                                           38033
# July                                           38614
# August                                         38772
# September                                      38374
#
# Consumption Category   2020 Household paper products Percent Change
# January                                        38042
# February                                       37937
# March                                          44706
# April                                          37601
# May                                            39052
# June                                           39452
# July                                           37998
# August                                         37965
# September                                      39656

# %%
#2019-2020 Percent Change by Month
paper_df.apply(lambda row: (row.iloc[1]-row.iloc[0])/row.iloc[0]*100, axis=1)
# Out:
# January      -1.153666
# February     -0.278632
# March        17.743422
# April        -1.901905
# May           2.409986
# June          3.730970
# July         -1.595276
# August       -2.081399
# September     3.340804
# dtype: float64
