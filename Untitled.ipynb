# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
from pprint import pprint

# %%
# Import data from CSV's
df = pd.read_csv('Resources/food_bev_data.csv')
df.head()
# Out:
#    Line                              Consumption Category   2015M01  2015M02  \
# 0    70                                   Nondurable goods  2660549  2667298
# 1    71      Food and beverages purchased for off-premi...   879429   880382
# 2    72        Food and nonalcoholic beverages purchase...   758255   758743
# 3    73          Food purchased for off-premises consum...   670298   670911
# 4    74                        Cereals and bakery products   131299   131481
#
#    2015M03  2015M04  2015M05  2015M06  2015M07  2015M08  ...  2019M12  \
# 0  2674394  2673472  2684923  2686891  2703838  2705901  ...  3008558
# 1   884258   882702   883590   884369   886810   884787  ...   987425
# 2   761143   760391   760844   760881   762501   760588  ...   846297
# 3   672565   672575   672796   672519   673834   672420  ...   747599
# 4   130979   130627   130858   130910   131009   131314  ...   142791
#
#    2020M01  2020M02  2020M03  2020M04  2020M05  2020M06  2020M07  2020M08  \
# 0  3021381  3021272  3169119  2755262  2978595  3109915  3134189  3116286
# 1   984969   981102  1201697  1028276  1050767  1043761  1058238  1045782
# 2   843738   839913  1035444   879610   892912   885363   899938   886682
# 3   745573   741871   920039   783298   794315   786017   798231   786446
# 4   143562   143129   177724   150935   155017   153845   155114   153090
#
#    2020M09
# 0  3170807
# 1  1049660
# 2   890498
# 3   789583
# 4   152942
#
# [5 rows x 71 columns]

# %%
#Making df just using the Meat & Fruit/Veggie rows & remove everything not 2020
food_df = df.loc[[df.index[7],df.index[18], df.index[19], df.index[20],df.index[21]]]
food_df.keys()
graph_df = food_df.drop(columns=["Line",'2015M01', '2015M02', '2015M03',
       '2015M04', '2015M05', '2015M06', '2015M07', '2015M08', '2015M09',
       '2015M10', '2015M11', '2015M12', '2016M01', '2016M02', '2016M03',
       '2016M04', '2016M05', '2016M06', '2016M07', '2016M08', '2016M09',
       '2016M10', '2016M11', '2016M12', '2017M01', '2017M02', '2017M03',
       '2017M04', '2017M05', '2017M06', '2017M07', '2017M08', '2017M09',
       '2017M10', '2017M11', '2017M12', '2018M01', '2018M02', '2018M03',
       '2018M04', '2018M05', '2018M06', '2018M07', '2018M08', '2018M09',
       '2018M10', '2018M11', '2018M12', '2019M01', '2019M02', '2019M03',
       '2019M04', '2019M05', '2019M06', '2019M07', '2019M08', '2019M09',
       '2019M10', '2019M11', '2019M12' ])
graph_df = graph_df.set_index("Consumption Category ")
graph_df
# Out:
#                                            2020M01  2020M02  2020M03  2020M04  \
# Consumption Category
#           Meats and poultry                 160228   159684   201253   170529
#           Fresh fruits and vegetables        85193    85144   106379    92262
#             Fruit (fresh)                    39759    39716    49421    42821
#             Vegetables (fresh)               45473    45466    56995    49470
#           Processed fruits and vegetables    30639    30674    38355    32704
#
#                                            2020M05  2020M06  2020M07  2020M08  \
# Consumption Category
#           Meats and poultry                 167545   162020   168507   168277
#           Fresh fruits and vegetables        93807    92650    92934    91172
#             Fruit (fresh)                    43849    43723    43801    42467
#             Vegetables (fresh)               50004    49001    49203    48742
#           Processed fruits and vegetables    33378    32978    33136    32600
#
#                                            2020M09
# Consumption Category
#           Meats and poultry                 169222
#           Fresh fruits and vegetables        91742
#             Fruit (fresh)                    43055
#             Vegetables (fresh)               48744
#           Processed fruits and vegetables    32502

# %%
months = graph_df.keys()

vegVSmeat, = plt.plot(months, graph_df.loc['Meats and poultry',["2020M01","2020M02","2020M03","2020M04","2020M05","2020M06","2020M07","2020M08","2020M09"]], 
                        color="red")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Meats and poultry'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-1dff95e9d37e> in <module>
#       1 months = graph_df.keys()
#       2
# ----> 3 vegVSmeat, = plt.plot(months, graph_df.loc['Meats and poultry',["2020M01","2020M02","2020M03","2020M04","2020M05","2020M06","2020M07","2020M08","2020M09"]],
#       4                         color="red")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#    1387         for i, key in enumerate(tup):
#    1388             if is_label_like(key) or isinstance(key, tuple):
# -> 1389                 section = self._getitem_axis(key, axis=i)
#    1390
#    1391                 # we have yielded a scalar ?
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Meats and poultry'
